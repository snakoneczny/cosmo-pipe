# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline 

import sys

sys.path.append('..')
from experiment import show_mcmc_report

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100
sns.set(style='ticks')
pd.set_option('mode.chained_assignment', None)

# %%
data_name = 'LoTSS_DR2'

# %% [markdown]
# # Subregions

# %%
# deep fields, errored, bias = 1.4, region dr1, C_gk only
experiment_name = 'gk__b_0_scaled__region-dr1'
show_mcmc_report(experiment_name, data_name, burnin=None, thin=None)
# Out:
# Mean acceptance fraction: 0.808278364116095
# Number of iterations: 1895
# burn-in: 41
# thin: 10
# flat chain shape: (185, 32, 1)
# flat log prob shape: (185, 32)
# $\displaystyle \mathrm{b_g} = 1.628_{-0.123}^{0.122}$
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'stat_func'
#   **contour_kws,

# %%
# deep fields, errored, bias = 1.4, region dr1
experiment_name = 'gg-gk__b_0_scaled__region-dr1'
show_mcmc_report(experiment_name, data_name, burnin=None, thin=None)
# Out:
# Mean acceptance fraction: 0.8059648898001025
# Number of iterations: 1951
# burn-in: 50
# thin: 12
# flat chain shape: (158, 32, 1)
# flat log prob shape: (158, 32)
# $\displaystyle \mathrm{b_g} = 1.571_{-0.076}^{0.072}$
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'stat_func'
#   **contour_kws,

# %%
# deep fields, errored, bias = 1.4, region 1
experiment_name = 'gg-gk__b_0_scaled__region-1'
show_mcmc_report(experiment_name, data_name, burnin=None, thin=None)
# Out:
# Mean acceptance fraction: 0.8083698248407643
# Number of iterations: 1256
# burn-in: 40
# thin: 10
# flat chain shape: (121, 32, 1)
# flat log prob shape: (121, 32)
# $\displaystyle \mathrm{b_g} = 1.374_{-0.081}^{0.079}$
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'stat_func'
#   **contour_kws,

# %%
# deep fields, errored, bias = 1.4, region 2
experiment_name = 'gg-gk__b_0_scaled__region-2'
show_mcmc_report(experiment_name, data_name, burnin=None, thin=None)
# Out:
# Mean acceptance fraction: 0.806573705179283
# Number of iterations: 1255
# burn-in: 44
# thin: 11
# flat chain shape: (110, 32, 1)
# flat log prob shape: (110, 32)
# $\displaystyle \mathrm{b_g} = 1.458_{-0.063}^{0.061}$
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'stat_func'
#   **contour_kws,

# %%
# deep fields, errored, bias = 1.4, region 3
experiment_name = 'gg-gk__b_0_scaled__region-3'
show_mcmc_report(experiment_name, data_name, burnin=None, thin=None)
# Out:
# Mean acceptance fraction: 0.8072622884770346
# Number of iterations: 1241
# burn-in: 51
# thin: 12
# flat chain shape: (99, 32, 1)
# flat log prob shape: (99, 32)
# $\displaystyle \mathrm{b_g} = 1.408_{-0.090}^{0.079}$
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'stat_func'
#   **contour_kws,

# %%
# deep fields, errored, bias = 1.4, region 4
experiment_name = 'gg-gk__b_0_scaled__region-4'
show_mcmc_report(experiment_name, data_name, burnin=None, thin=None)
# Out:
# Mean acceptance fraction: 0.8062658227848101
# Number of iterations: 1975
# burn-in: 43
# thin: 10
# flat chain shape: (193, 32, 1)
# flat log prob shape: (193, 32)
# $\displaystyle \mathrm{b_g} = 1.505_{-0.053}^{0.051}$
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'stat_func'
#   **contour_kws,

# %%
# deep fields, errored, bias = 1.4, region 5
experiment_name = 'gg-gk__b_0_scaled__region-5'
show_mcmc_report(experiment_name, data_name, burnin=None, thin=None)
# Out:
# Mean acceptance fraction: 0.8016690340909092
# Number of iterations: 1232
# burn-in: 37
# thin: 9
# flat chain shape: (132, 32, 1)
# flat log prob shape: (132, 32)
# $\displaystyle \mathrm{b_g} = 1.463_{-0.046}^{0.047}$
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'stat_func'
#   **contour_kws,

# %%
# deep fields, errored, bias = 1.4, region 6
experiment_name = 'gg-gk__b_0_scaled__region-6'
show_mcmc_report(experiment_name, data_name, burnin=None, thin=None)
# Out:
# Mean acceptance fraction: 0.802594529364441
# Number of iterations: 1243
# burn-in: 43
# thin: 10
# flat chain shape: (120, 32, 1)
# flat log prob shape: (120, 32)
# $\displaystyle \mathrm{b_g} = 1.636_{-0.048}^{0.046}$
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'stat_func'
#   **contour_kws,

# %%
# deep fields, errored, bias = 1.4, big patch
experiment_name = 'gg-gk__b_0_scaled__big-patch'
show_mcmc_report(experiment_name, data_name, burnin=None, thin=None)
# Out:
# Mean acceptance fraction: 0.8057442632850242
# Number of iterations: 2484
# burn-in: 49
# thin: 12
# flat chain shape: (202, 32, 1)
# flat log prob shape: (202, 32)
# $\displaystyle \mathrm{b_g} = 1.500_{-0.023}^{0.023}$
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'stat_func'
#   **contour_kws,

# %%
# deep fields, errored, bias = 1.4, small patch
experiment_name = 'gg-gk__b_0_scaled__small-patch'
show_mcmc_report(experiment_name, data_name, burnin=None, thin=None)
# Out:
# Mean acceptance fraction: 0.8061573215940686
# Number of iterations: 2158
# burn-in: 43
# thin: 10
# flat chain shape: (211, 32, 1)
# flat log prob shape: (211, 32)
# $\displaystyle \mathrm{b_g} = 1.603_{-0.040}^{0.039}$
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'stat_func'
#   **contour_kws,

# %% [markdown]
# # gg vs gk

# %%
# deep fields, errored, bias = 1.5
experiment_name = 'gg-gk__b_0_scaled__bias-1-5'
show_mcmc_report(experiment_name, data_name, burnin=None, thin=None)
# Out:
# Mean acceptance fraction: 0.8053579895685159
# Number of iterations: 2109
# burn-in: 42
# thin: 10
# flat chain shape: (206, 32, 1)
# flat log prob shape: (206, 32)
# $\displaystyle \mathrm{b_g} = 1.478_{-0.021}^{0.021}$
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'stat_func'
#   **contour_kws,

# %%
# deep fields, errored, bias = 1.4, gg only
experiment_name = 'gg__b_0_scaled__gg-only'
show_mcmc_report(experiment_name, data_name, burnin=None, thin=None)
# Out:
# Mean acceptance fraction: 0.8022789914250714
# Number of iterations: 2449
# burn-in: 48
# thin: 12
# flat chain shape: (200, 32, 1)
# flat log prob shape: (200, 32)
# $\displaystyle \mathrm{b_g} = 1.479_{-0.020}^{0.021}$
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'stat_func'
#   **contour_kws,

# %%
# deep fields, errored, bias = 1.4, gk only
experiment_name = 'gk__b_0_scaled__gk-only'
show_mcmc_report(experiment_name, data_name, burnin=None, thin=None)
# Out:
# Mean acceptance fraction: 0.7932291666666667
# Number of iterations: 420
# burn-in: 29
# thin: 7
# flat chain shape: (55, 32, 1)
# flat log prob shape: (55, 32)
# $\displaystyle \mathrm{b_g} = 1.402_{-0.036}^{0.039}$
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'stat_func'
#   **contour_kws,

# %%
# deep fields, errored, bias = 1.4
experiment_name = 'gg-gk__b_0_scaled__test-0'
show_mcmc_report(experiment_name, data_name, burnin=None, thin=None)
# Out:
# Mean acceptance fraction: 0.8038897679324895
# Number of iterations: 2370
# burn-in: 47
# thin: 11
# flat chain shape: (211, 32, 1)
# flat log prob shape: (211, 32)
# $\displaystyle \mathrm{b_g} = 1.479_{-0.021}^{0.020}$
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/snakoneczny/tools/anaconda3/envs/py37_isw/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'stat_func'
#   **contour_kws,
